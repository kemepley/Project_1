# %%
import pandas as pd

# %%
house = pd.read_csv('https://raw.githubusercontent.com/learn-co-students/dsc-v2-mod1-final-project-dc-ds-career-042219/master/kc_house_data.csv')

# %%
house.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
house.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
pd.to_datetime(house.date)
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
# 5       2014-05-12
# 6       2014-06-27
# 7       2015-01-15
# 8       2015-04-15
# 9       2015-03-12
# 10      2015-04-03
# 11      2014-05-27
# 12      2014-05-28
# 13      2014-10-07
# 14      2015-03-12
# 15      2015-01-24
# 16      2014-07-31
# 17      2014-05-29
# 18      2014-12-05
# 19      2015-04-24
# 20      2014-05-14
# 21      2014-08-26
# 22      2014-07-03
# 23      2014-05-16
# 24      2014-11-20
# 25      2014-11-03
# 26      2014-06-26
# 27      2014-12-01
# 28      2014-06-24
# 29      2015-03-02
#            ...
# 21567   2014-06-10
# 21568   2014-12-02
# 21569   2014-08-28
# 21570   2014-10-15
# 21571   2015-03-05
# 21572   2014-11-13
# 21573   2014-09-10
# 21574   2014-05-14
# 21575   2014-10-02
# 21576   2015-04-16
# 21577   2015-03-17
# 21578   2014-10-17
# 21579   2014-10-31
# 21580   2014-08-13
# 21581   2015-04-21
# 21582   2014-10-13
# ...

# %%
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
duplicates = house[house.duplicated()]
print(len(duplicates))
# Out:
# 0

# %%
for col in house.columns:
    print(col, '\n', house[col].value_counts(normalize=True).head(), '\n\n')
# Out:
# id
#  795000620     0.000139
# 1825069031    0.000093
# 2019200220    0.000093
# 7129304540    0.000093
# 1781500435    0.000093
# Name: id, dtype: float64
#
#
# date
#  6/23/2014    0.006575
# 6/26/2014    0.006066
# 6/25/2014    0.006066
# 7/8/2014     0.005880
# 4/27/2015    0.005834
# Name: date, dtype: float64
#
#
# price
#  350000.0    0.007964
# 450000.0    0.007964
# 550000.0    0.007362
# 500000.0    0.007038
# 425000.0    0.006945
# Name: price, dtype: float64
#
#
# bedrooms
#  3    0.454878
# 4    0.318655
# 2    0.127796
# 5    0.074131
# 6    0.012594
# Name: bedrooms, dtype: float64
#
#
# bathrooms
#  2.50    0.248970
# 1.00    0.178312
# 1.75    0.141131
# 2.25    0.094782
# 2.00    0.089364
# Name: bathrooms, dtype: float64
#
#
# sqft_living
#  1300    0.006390
# 1400    0.006251
# 1440    0.006158
# 1660    0.005973
# 1010    0.005973
# Name: sqft_living, dtype: float64
#
#
# sqft_lot
#  5000    0.016576
# 6000    0.013428
# 4000    0.011622
# 7200    0.010187
# ...

# %%
house['waterfront'].value_counts(dropna=False)
# Out:
# 0.0    19075
# NaN     2376
# 1.0      146
# Name: waterfront, dtype: int64

# %%
house['view'].value_counts(dropna=False)
# Out:
# 0.0    19422
# 2.0      957
# 3.0      508
# 1.0      330
# 4.0      317
# NaN       63
# Name: view, dtype: int64

# %%
house['yr_renovated'].value_counts(dropna=False)
# Out:
# 0.0       17011
# NaN        3842
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
# 2005.0       29
# 2000.0       29
# 1990.0       22
# 2004.0       22
# 2009.0       21
# 1989.0       20
# 2006.0       20
# 2002.0       17
# 1991.0       16
# 1998.0       16
# 1984.0       16
# 1999.0       15
# 2001.0       15
# 2008.0       15
# 2010.0       15
# 1983.0       15
# 2015.0       14
# 1986.0       14
# 1987.0       14
# 1994.0       14
# 1985.0       14
# 1992.0       13
# 1995.0       12
# 1997.0       12
#           ...
# 1964.0        5
# 1975.0        5
# 1973.0        4
# 1981.0        4
# 1963.0        4
# 1969.0        4
# 1965.0        4
# 1972.0        3
# 1956.0        3
# 1945.0        3
# 1960.0        3
# 1978.0        3
# 1958.0        3
# 1955.0        3
# 1974.0        2
# 1962.0        2
# 1967.0        2
# 1940.0        2
# 1957.0        2
# 1946.0        1
# 1959.0        1
# 1951.0        1
# 1954.0        1
# 1950.0        1
# ...

# %%
house['sqft_basement'].value_counts(dropna=False)
# Out:
# 0.0       12826
# ?           454
# 600.0       217
# 500.0       209
# 700.0       208
# 800.0       201
# 400.0       184
# 1000.0      148
# 900.0       142
# 300.0       142
# 200.0       105
# 750.0       104
# 450.0       103
# 480.0       103
# 530.0       103
# 720.0        98
# 620.0        90
# 580.0        84
# 840.0        83
# 420.0        81
# 860.0        79
# 1100.0       78
# 670.0        78
# 780.0        76
# 550.0        76
# 650.0        75
# 240.0        74
# 380.0        73
# 680.0        73
# 360.0        72
#           ...
# 768.0         1
# 652.0         1
# 2390.0        1
# 475.0         1
# 1960.0        1
# 2240.0        1
# 225.0         1
# 1275.0        1
# 1008.0        1
# 283.0         1
# 1281.0        1
# 906.0         1
# 1248.0        1
# 508.0         1
# 3480.0        1
# 602.0         1
# 248.0         1
# 2360.0        1
# 1548.0        1
# 2250.0        1
# 1913.0        1
# 792.0         1
# 935.0         1
# 704.0         1
# ...

# %%
house['view'].plot.box()

# %%
house.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002386   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.078523   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
house[['sqft_living', 'sqft_lot', 'yr_renovated','sqft_living15', 'sqft_lot15']]
# Out:
#        sqft_living  sqft_lot  yr_renovated  sqft_living15  sqft_lot15
# 0             1180      5650           0.0           1340        5650
# 1             2570      7242        1991.0           1690        7639
# 2              770     10000           NaN           2720        8062
# 3             1960      5000           0.0           1360        5000
# 4             1680      8080           0.0           1800        7503
# 5             5420    101930           0.0           4760      101930
# 6             1715      6819           0.0           2238        6819
# 7             1060      9711           0.0           1650        9711
# 8             1780      7470           0.0           1780        8113
# 9             1890      6560           0.0           2390        7570
# 10            3560      9796           0.0           2210        8925
# 11            1160      6000           0.0           1330        6000
# ...
