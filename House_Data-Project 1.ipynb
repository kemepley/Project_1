# %%
#import necessary python libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
#import dataset
house = pd.read_csv('https://raw.githubusercontent.com/learn-co-students/dsc-v2-mod1-final-project-dc-ds-career-042219/master/kc_house_data.csv')

# %%
#view the first 5 entries of the dataset
house.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
#view the last 5 entries of the dataset
house.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
#show how many rows, columns are in the dataframe and the datatype of each column
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
# #convert date column from 'object' to datetime then save to dataframe
# house['date'] = pd.to_datetime(house.date, format='%m/%d/%Y')

# %%
#check to make sure date column changed
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
#give a statistical summary of all the numeric variables
house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
#check for duplicate data
duplicates = house[house.duplicated()]
print(len(duplicates))
# Out:
# 0

# %%
for col in house.columns:
    print(col, '\n', house[col].value_counts(normalize=True).head(), '\n\n')
# Out:
# id
#  795000620     0.000139
# 1825069031    0.000093
# 2019200220    0.000093
# 7129304540    0.000093
# 1781500435    0.000093
# Name: id, dtype: float64
#
#
# date
#  6/23/2014    0.006575
# 6/26/2014    0.006066
# 6/25/2014    0.006066
# 7/8/2014     0.005880
# 4/27/2015    0.005834
# Name: date, dtype: float64
#
#
# price
#  350000.0    0.007964
# 450000.0    0.007964
# 550000.0    0.007362
# 500000.0    0.007038
# 425000.0    0.006945
# Name: price, dtype: float64
#
#
# bedrooms
#  3    0.454878
# 4    0.318655
# 2    0.127796
# 5    0.074131
# 6    0.012594
# Name: bedrooms, dtype: float64
#
#
# bathrooms
#  2.50    0.248970
# 1.00    0.178312
# 1.75    0.141131
# 2.25    0.094782
# 2.00    0.089364
# Name: bathrooms, dtype: float64
#
#
# sqft_living
#  1300    0.006390
# 1400    0.006251
# 1440    0.006158
# 1660    0.005973
# 1010    0.005973
# Name: sqft_living, dtype: float64
#
#
# sqft_lot
#  5000    0.016576
# 6000    0.013428
# 4000    0.011622
# 7200    0.010187
# ...

# %%
#correlation matrix to show correlation between variables
house.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002386   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.078523   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
#use a heatmap with the correlation matrix
ax = sns.heatmap(house.corr())

# %%
#Annotated heatmap to associate values to the variables
corrmat = house.corr()
k = 5 #number of variables for heatmap
cols = corrmat.nlargest(k, 'price')['price'].index
cm = np.corrcoef(house[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm,annot=True, fmt='.3f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
#check columns names
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
#drop some unnecessary columns to prepare for pairplot and save to new dataframe
quickview = house.drop(columns=['id', 'date', 'view','yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'])

# %%
#pairplot shows the relationship between different variables
sns.pairplot(quickview)
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
#show plot of highly correlated items
sns.set()
cols = ['sqft_living', 'sqft_above', 'grade', 'sqft_living15'] 
sns.pairplot(house[cols], size = 3.5)
plt.show();
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#sort database in ascending order by price and save to new dataframe
expense = house.sort_values(by=['price'])
expense
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 15279    40000362    5/6/2014    78000.0         2       1.00          780
# 465    8658300340   5/23/2014    80000.0         1       0.75          430
# 16184  3028200080   3/24/2015    81000.0         2       1.00          730
# 8267   3883800011   11/5/2014    82000.0         3       1.00          860
# 2139   1623049041    5/8/2014    82500.0         2       1.00          520
# 18453  7999600180   5/29/2014    83000.0         2       1.00          900
# 3763   1523049188   4/30/2015    84000.0         2       1.00          700
# 10242  2422049104   9/15/2014    85000.0         2       1.00          830
# 16700  1322049150    3/5/2015    85000.0         2       1.00          910
# 13743  1788900230   7/22/2014    86500.0         3       1.00          840
# 5860   9320900420  10/14/2014    89000.0         3       1.00          900
# ...

# %%
#select the 10 least expensive homes
least = expense.iloc[0:9]
least
# Out:
#                id       date    price  bedrooms  bathrooms  sqft_living  \
# 15279    40000362   5/6/2014  78000.0         2       1.00          780
# 465    8658300340  5/23/2014  80000.0         1       0.75          430
# 16184  3028200080  3/24/2015  81000.0         2       1.00          730
# 8267   3883800011  11/5/2014  82000.0         3       1.00          860
# 2139   1623049041   5/8/2014  82500.0         2       1.00          520
# 18453  7999600180  5/29/2014  83000.0         2       1.00          900
# 3763   1523049188  4/30/2015  84000.0         2       1.00          700
# 10242  2422049104  9/15/2014  85000.0         2       1.00          830
# 16700  1322049150   3/5/2015  85000.0         2       1.00          910
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15279     16344     1.0         0.0   0.0  ...      5         780
# 465        5050     1.0         NaN   0.0  ...      4         430
# ...

# %%
# select the 10 most expensive homes
most = expense.iloc[-10:]
most
# Out:
#               id        date      price  bedrooms  bathrooms  sqft_living  \
# 8629  3835500195   6/18/2014  4490000.0         4       3.00         6430
# 2624  7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8085  1924059029   6/17/2014  4670000.0         5       6.75         9640
# 1162  1247600105  10/20/2014  5110000.0         5       5.25         8010
# 1313  7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1446  8907500070   4/13/2015  5350000.0         5       5.00         8000
# 4407  2470100110    8/4/2014  5570000.0         5       5.75         9200
# 9245  9208900037   9/19/2014  6890000.0         6       7.75         9890
# 3910  9808700762   6/11/2014  7060000.0         5       4.50        10040
# 7245  6762700020  10/13/2014  7700000.0         6       8.00        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 8629     27517     2.0         0.0   0.0  ...     12        6430
# ...

# %%
#a barplot to show the distribution of most expensive home prices by zipcodes
import seaborn as sns
sns.set(style="whitegrid")
ax = sns.barplot(x="zipcode", y="price", data=most)

# %%
##a barplot to show the distribution of least expensive homes price by zipcodes
sns.set(style="whitegrid")
ax = sns.barplot(x="zipcode", y="price", data=least)

# %% [markdown]
# Grading system of homes in King County
#
# Represents the construction quality of improvements. Grades run from grade 1 to 13. Generally defined as:
#
# 1-3 Falls short of minimum building standards. Normally cabin or inferior structure.
#
# 4 Generally older, low quality construction. Does not meet code.
#
# 5 Low construction costs and workmanship. Small, simple design.
#
# 6 Lowest grade currently meeting building code. Low quality materials and simple designs.
#
# 7 Average grade of construction and design. Commonly seen in plats and older sub-divisions.
#
# 8 Just above average in construction and design. Usually better materials in both the exterior and interior finish work.
#
# 9 Better architectural design with extra interior and exterior design and quality.
#
# 10 Homes of this quality generally have high quality features. Finish work is better and more design quality is seen in the floor plans. Generally have a larger square footage.
#
# 11 Custom design and higher quality finish work with added amenities of solid woods, bathroom fixtures and more luxurious options.
#
# 12 Custom design and excellent builders. All materials are of the highest quality and all conveniences are present.
#
# 13 Generally custom designed and built. Mansion level. Large amount of highest quality cabinet work, wood trim, marble, entry ways etc.

# %% [markdown]
# Coding system of King County
#
# Relative to age and grade. Coded 1-5.
#
# 1 = Poor- Worn out. Repair and overhaul needed on painted surfaces, roofing, plumbing, heating and numerous functional inadequacies. Excessive deferred maintenance and abuse, limited value-in-use, approaching abandonment or major reconstruction; reuse or change in occupancy is imminent. Effective age is near the end of the scale regardless of the actual chronological age.
#
# 2 = Fair- Badly worn. Much repair needed. Many items need refinishing or overhauling, deferred maintenance obvious, inadequate building utility and systems all shortening the life expectancy and increasing the effective age.
#
# 3 = Average- Some evidence of deferred maintenance and normal obsolescence with age in that a few minor repairs are needed, along with some refinishing. All major components still functional and contributing toward an extended life expectancy. Effective age and utility is standard for like properties of its class and usage.
#
# 4 = Good- No obvious maintenance required but neither is everything new. Appearance and utility are above the standard and the overall effective age will be lower than the typical property.
#
# 5= Very Good- All items well maintained, many having been overhauled and repaired as they have shown signs of wear, increasing the life expectancy and lowering the effective age with little deterioration or obsolescence evident with a high degree of utility.

# %%
#see the values of each grade
house['grade'].value_counts()
# Out:
# 7     8974
# 8     6065
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      89
# 4       27
# 13      13
# 3        1
# Name: grade, dtype: int64

# %%
#plot of home size versus price and distinguished by grade
sns.scatterplot(x="sqft_living", y="price", data=house, hue='grade')
plt.title('Average Grade Home vs Cost')
# Set x-axis label
plt.xlabel('Home Footage (Sq.ft)')
# Set y-axis label
plt.ylabel('Price($)')
# Out:
# Text(0, 0.5, 'Price($)')

# %%
#plot of home size versus price and distinguished by grade(a little more focused)
sns.scatterplot(x="sqft_living", y="price", data=house, hue='grade')
plt.title('Average Grade Home vs Cost')
# Set x-axis label
plt.xlabel('Home Footage (Sq.ft)')
# Set y-axis label
plt.ylabel('Price($)')
plt.xlim((0, 10000))
# Out:
# (0, 10000)

# %%
floor_levels = house.groupby('floors')['price'].mean()
floor_levels
# Out:
# floors
# 1.0    4.423584e+05
# 1.5    5.590449e+05
# 2.0    6.491856e+05
# 2.5    1.061021e+06
# 3.0    5.834339e+05
# 3.5    9.102143e+05
# Name: price, dtype: float64

# %%
sns.barplot(x="floors", y="price", data=house, ci=None, color='b')
plt.title('Number of Floors in a House')
# Set x-axis label
plt.xlabel('Floor levels')
# Set y-axis label
plt.ylabel('Average Home Price($)')
# Out:
# Text(0, 0.5, 'Average Home Price($)')

# %%
#convert date column to months formant instead of month/day/year
house['month'] = house['date'].apply(lambda i: i[:2])
house['month'] = house['month'].apply(lambda i: i.replace("/", ""))
house['month'].astype(int)
# Out:
# 0        10
# 1        12
# 2         2
# 3        12
# 4         2
# 5         5
# 6         6
# 7         1
# 8         4
# 9         3
# 10        4
# 11        5
# 12        5
# 13       10
# 14        3
# 15        1
# 16        7
# 17        5
# 18       12
# 19        4
# 20        5
# 21        8
# 22        7
# 23        5
# 24       11
# 25       11
# 26        6
# 27       12
# 28        6
# 29        3
#          ..
# 21567     6
# 21568    12
# 21569     8
# 21570    10
# 21571     3
# 21572    11
# 21573     9
# 21574     5
# 21575    10
# 21576     4
# 21577     3
# 21578    10
# 21579    10
# 21580     8
# 21581     4
# 21582    10
# 21583     9
# 21584    10
# 21585     4
# 21586     6
# 21587     8
# 21588     1
# 21589    10
# 21590     3
# 21591     2
# 21592     5
# 21593     2
# 21594     6
# 21595     1
# 21596    10
# Name: month, Length: 21597, dtype: int64

# %%
#get the average price of houses grouped by month
avgsalesbymonth = house.groupby('month')['price'].mean()
avgsalesbymonth
# Out:
# month
# 1     525963.251534
# 10    539439.447228
# 11    522359.903478
# 12    524799.902041
# 2     508520.051323
# 3     544057.683200
# 4     562215.615074
# 5     550849.746893
# 6     557534.318182
# 7     544892.161013
# 8     536655.212481
# 9     529723.517787
# Name: price, dtype: float64

# %%
#get the total number of houses sold by month
avgcountsbymonth = house['month'].value_counts()
avgcountsbymonth
# Out:
# 5     2414
# 4     2229
# 7     2211
# 6     2178
# 8     1939
# 10    1876
# 3     1875
# 9     1771
# 12    1470
# 11    1409
# 2     1247
# 1      978
# Name: month, dtype: int64

# %%
#make the average sales by month a dataframe so that it can be sorted
df = avgsalesbymonth
df = df.reset_index()
df['month'] = df['month'].astype(int)
df = df.sort_values(by = 'month').reset_index(drop=True)
df
# Out:
#     month          price
# 0       1  525963.251534
# 1       2  508520.051323
# 2       3  544057.683200
# 3       4  562215.615074
# 4       5  550849.746893
# 5       6  557534.318182
# 6       7  544892.161013
# 7       8  536655.212481
# 8       9  529723.517787
# 9      10  539439.447228
# 10     11  522359.903478
# 11     12  524799.902041

# %%
#rename the index of the dataframe
average_sale = df.rename(index = {0:'January',1:'February',2:'March',3:'April',4:'May',5:'June',6:'July',7:'August',
            8:'September',9:'October',10:'November',11:'December'})
average_sale
# Out:
#            month          price
# January        1  525963.251534
# February       2  508520.051323
# March          3  544057.683200
# April          4  562215.615074
# May            5  550849.746893
# June           6  557534.318182
# July           7  544892.161013
# August         8  536655.212481
# September      9  529723.517787
# October       10  539439.447228
# November      11  522359.903478
# December      12  524799.902041

# %%
#drop the month column
average_sale = average_sale.drop(columns = 'month')
average_sale
# Out:
#                    price
# January    525963.251534
# February   508520.051323
# March      544057.683200
# April      562215.615074
# May        550849.746893
# June       557534.318182
# July       544892.161013
# August     536655.212481
# September  529723.517787
# October    539439.447228
# November   522359.903478
# December   524799.902041

# %%
#plot of average prices by month
average_sale.plot(y ='price', use_index=True, figsize = (10,8), kind = 'bar', colormap='Dark2',
                  title = 'Average Sales of Homes by Month')
plt.xlabel('Month')
plt.ylabel('Price ($)')
# Out:
# Text(0, 0.5, 'Price ($)')

# %%
#make the average counts by month a dataframe so that it can be sorted
df2 = avgcountsbymonth
df2 = df2.reset_index()
df2['index'] = df2['index'].astype(int)
df2 = df2.sort_values(by = 'index').reset_index(drop=True)
df2
# Out:
#     index  month
# 0       1    978
# 1       2   1247
# 2       3   1875
# 3       4   2229
# 4       5   2414
# 5       6   2178
# 6       7   2211
# 7       8   1939
# 8       9   1771
# 9      10   1876
# 10     11   1409
# 11     12   1470

# %%
#rename the index of the dataframe
average_count = df2.rename(index = {0:'January',1:'February',2:'March',3:'April',4:'May',5:'June',
                    6:'July',7:'August',8:'September',9:'October',10:'November',11:'December'})
average_count
# Out:
#            index  month
# January        1    978
# February       2   1247
# March          3   1875
# April          4   2229
# May            5   2414
# June           6   2178
# July           7   2211
# August         8   1939
# September      9   1771
# October       10   1876
# November      11   1409
# December      12   1470

# %%
#plot of average counts by month
average_count.plot(y = 'month', use_index= True, figsize = (10,8), kind = 'bar', 
                      title = 'Average Counts of Homes by Month')
plt.xlabel('Month')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
